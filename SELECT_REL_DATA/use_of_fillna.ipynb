# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("base_data3.csv")

df.UPTAKE_AVG = df.UPTAKE_AVG.fillna(q)
df.CORR_COAL_RATE = df.CORR_COAL_RATE.median()
df.HM_TEMP = df.HM_TEMP.median()
df.COK_CSR = df.COK_CSR.median()
df.COK_CRI = df.COK_CRI.median()
df.SIN_CAO_SIO2 = df.SIN_CAO_SIO2.median()
df.SIN_MGO = df.SIN_MGO.median()
df.head(30)
# Out:
#        CLASS       DT  YEAR  HML_SI  ...  COK_CRI COK_AMS  SIN_CAO_SIO2  SIN_MGO
# 0   TRAINING   1/1/14  2014   0.895  ...     25.8  48.902           2.5    1.838
# 1   TRAINING   1/2/14  2014   0.845  ...     25.8  47.798           2.5    1.838
# 2   TRAINING   1/4/14  2014   0.899  ...     25.8  48.862           2.5    1.838
# 3   TRAINING   1/5/14  2014   0.784  ...     25.8  48.332           2.5    1.838
# 4   TRAINING   1/6/14  2014   0.827  ...     25.8  49.944           2.5    1.838
# 5   TRAINING   1/7/14  2014   0.865  ...     25.8  49.972           2.5    1.838
# 6   TRAINING   1/9/14  2014   0.845  ...     25.8  49.164           2.5    1.838
# 7   TRAINING  1/10/14  2014   0.863  ...     25.8  48.759           2.5    1.838
# 8   TRAINING  1/11/14  2014   0.933  ...     25.8  49.272           2.5    1.838
# 9   TRAINING  1/12/14  2014   0.850  ...     25.8  48.682           2.5    1.838
# 10  TRAINING  1/13/14  2014   0.834  ...     25.8  49.148           2.5    1.838
# 11  TRAINING  1/15/14  2014   0.841  ...     25.8  50.084           2.5    1.838
# 12  TRAINING  1/16/14  2014   0.881  ...     25.8  45.624           2.5    1.838
# 13  TRAINING  1/17/14  2014   0.769  ...     25.8  45.340           2.5    1.838
# 14  TRAINING  1/18/14  2014   0.844  ...     25.8  40.244           2.5    1.838
# 15  TRAINING  1/20/14  2014   0.842  ...     25.8  45.517           2.5    1.838
# 16  TRAINING  1/21/14  2014   0.877  ...     25.8  37.231           2.5    1.838
# 17  TRAINING  1/22/14  2014   0.903  ...     25.8  41.686           2.5    1.838
# 18  TRAINING  1/23/14  2014   0.910  ...     25.8  37.810           2.5    1.838
# 19  TRAINING  1/26/14  2014   0.766  ...     25.8  37.153           2.5    1.838
# 20  TRAINING  1/27/14  2014   0.760  ...     25.8  38.517           2.5    1.838
# 21  TRAINING  1/28/14  2014   0.847  ...     25.8  37.170           2.5    1.838
# 22  TRAINING  1/29/14  2014   0.804  ...     25.8  37.638           2.5    1.838
# 23  TRAINING  1/30/14  2014   0.703  ...     25.8  38.434           2.5    1.838
# 24  TRAINING  1/31/14  2014   0.752  ...     25.8  39.820           2.5    1.838
# 25  TRAINING   2/1/14  2014   0.764  ...     25.8  38.504           2.5    1.838
# 26  TRAINING   2/2/14  2014   0.913  ...     25.8  38.493           2.5    1.838
# 27  TRAINING   2/3/14  2014   0.708  ...     25.8  37.843           2.5    1.838
# 28  TRAINING   2/4/14  2014   0.776  ...     25.8  37.732           2.5    1.838
# 29  TRAINING   2/5/14  2014   0.803  ...     25.8  39.273           2.5    1.838
#
# [30 rows x 42 columns]
